# %%
import pyoccam
import os

# %%
test_download_path = r"D:\projects\occam\pyoccam\import_test"
os.chdir(test_download_path)
pyoccam.get_demo_notebook(copy_to_current=True)
pyoccam.get_demo_script(copy_to_current=True)
# Out:
# ✓ Copied notebook to: D:\projects\occam\pyoccam\import_test\minimal_occam_notebook.ipynb
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 4
#       2 os.chdir(test_download_path)
#       3 pyoccam.get_demo_notebook(copy_to_current=True)
# ----> 4 pyoccam.get_demo_script(copy_to_current=True)
#
# File D:\projects\occam\pyoccam\__init__.py:199, in get_demo_script(copy_to_current)
#     196 demo_file = PACKAGE_DIR / "pyoccam_demo.py"
#     198 if not demo_file.exists():
# --> 199     raise FileNotFoundError(f"Demo script not found at {demo_file}")
#     201 if copy_to_current:
#     202     import shutil
#
# FileNotFoundError: Demo script not found at D:\projects\occam\pyoccam\pyoccam_demo.py
