# %%
# !pip install -i https://test.pypi.org/simple/ pyoccam==0.1.1
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# Collecting pyoccam==0.1.1
#   Downloading https://test-files.pythonhosted.org/packages/0a/8c/7c216ff684ed3ae60d0659732068d276d7f97d6e187fc27b633236c85e04/pyoccam-0.1.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pyoccam==0.1.1) (2.0.2)
# Downloading https://test-files.pythonhosted.org/packages/0a/8c/7c216ff684ed3ae60d0659732068d276d7f97d6e187fc27b633236c85e04/pyoccam-0.1.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 11.0 MB/s eta 0:00:00
# Installing collected packages: pyoccam
# Successfully installed pyoccam-0.1.1

# %%
# Install - just run the cell above this one to install pyoccam once in this session
#!pip install -i https://test.pypi.org/simple/ pyoccam==0.1.1

# Test that data files are included
import pyoccam
from pathlib import Path

pkg_dir = Path(pyoccam.__file__).parent
data_file = pkg_dir / "dementia05.txt"

print(f"Data file exists: {data_file.exists()}")

# Run analysis
manager = pyoccam.VBMManager()
manager.init_from_command_line(["occam", str(data_file)])
print(f"Sample size: {manager.get_sample_size()}")
# Out:
# Data file exists: True
# Sample size: 424

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Import required libraries
import pyoccam
import sys
import os
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# Check pyoccam2 version
print(f"pyoccam version: {pyoccam.__version__}")
print(f"Python version: {sys.version}")
print(f"Notebook run: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# pyoccam version: 0.1.0
# Python version: 3.12.11 (main, Jun  4 2025, 08:56:18) [GCC 11.4.0]
# Notebook run: 2025-09-17 05:46:29

# %%
##%%
# CONFIGURATION - Modify these settings as needed

# Data Configuration
# DATA_FILE = "landslides.txt" # Original line
# Use the data file included with the pyoccam package
import pyoccam
from pathlib import Path
pkg_dir = Path(pyoccam.__file__).parent
DATA_FILE = pkg_dir / "dementia05.txt"

# Search Configuration
SEARCH_TYPE = "full-up"    # Options: loopless-up, full-up, disjoint-up, chain-up
SEARCH_LEVELS = 7
SEARCH_WIDTH = 3
ALPHA_THRESHOLD = 0.05

# Model Selection
BEST_MODEL_CRITERION = "bic"    # Options: bic, aic, information, info_alpha

# Output Configuration
OUTPUT_DIR = "notebook_output"
OUTPUT_FORMAT = "space"         # Options: space, csv, tab, html

# Fit Report Configuration
GENERATE_FIT_REPORT = True
FIT_TARGET_STATE = "0"
SKIP_RESIDUALS = False
SKIP_IVI_TABLES = False

# Debug
DEBUG_MODE = False

print("Configuration loaded successfully")
print(f"Data file: {DATA_FILE}")
print(f"Search type: {SEARCH_TYPE}")
print(f"Model selection: {BEST_MODEL_CRITERION}")
# Out:
# Configuration loaded successfully
# Data file: /usr/local/lib/python3.12/dist-packages/pyoccam/dementia05.txt
# Search type: full-up
# Model selection: bic

# %%
##%%
# Helper functions

def create_output_directory():
    """Create output directory if it doesn't exist"""
    if not os.path.exists(OUTPUT_DIR):
        os.makedirs(OUTPUT_DIR)
        print(f"Created output directory: {OUTPUT_DIR}")
    else:
        print(f"Output directory exists: {OUTPUT_DIR}")

def get_separator_constant(format_name):
    """Convert format name to pyoccam2 separator constant"""
    separators = {
        "tab": pyoccam.TABSEP,
        "csv": pyoccam.COMMASEP,
        "space": pyoccam.SPACESEP,
        "html": pyoccam.HTMLFORMAT
    }
    return separators.get(format_name.lower(), pyoccam.SPACESEP)

def save_output(content, filename):
    """Save output to file"""
    filepath = os.path.join(OUTPUT_DIR, filename)
    with open(filepath, 'w') as f:
        f.write(content)
    print(f"Saved to: {filepath}")
    return filepath

# Create output directory
create_output_directory()
# Out:
# Output directory exists: notebook_output

# %%
##%%
# Initialize OCCAM manager
manager = pyoccam.VBMManager()

# Enable debug mode if configured
if DEBUG_MODE:
    manager.set_debug_mode(True)
    print("Debug mode: ENABLED")

# Load data file
print(f"Loading: {DATA_FILE}")
success = manager.init_from_command_line(["occam", str(DATA_FILE)])

if not success:
    raise Exception(f"Failed to load data file '{DATA_FILE}'")

print("✓ Data loaded successfully")
# Out:
# Loading: /usr/local/lib/python3.12/dist-packages/pyoccam/dementia05.txt
# ✓ Data loaded successfully

# %%
##%%
# Display basic statistics
stats = manager.get_basic_statistics()
print("Data Statistics:")
print(stats)

# Check for test data
has_test = manager.has_test_data()
if has_test:
    print("\n✓ Test data detected - will include test performance metrics")
else:
    print("\nℹ No test data found - using training data only")

# Get variable information
variables = manager.get_variable_list()
print(f"\nVariables ({len(variables)}):")
if len(variables) <= 10:
    for i, var in enumerate(variables):
        print(f"  {i+1:2d}. {var}")
else:
    # Show first and last few
    for i in range(3):
        print(f"  {i+1:2d}. {variables[i]}")
    print("  ...")
    for i in range(len(variables)-2, len(variables)):
        print(f"  {i+1:2d}. {variables[i]}")
# Out:
# Data Statistics:
# Sample size: 424
# Variables: 19
# H(data): 9.72662
# Test data: None
#
#
# ℹ No test data found - using training data only
#
# Variables (19):
#    1. APOE
#    2. Gender
#    3. Education
#   ...
#   18. rs3865444
#   19. CaseControl

# %%
##%%
# Initialize OCCAM manager
manager = pyoccam.VBMManager()

# Enable debug mode if configured
if DEBUG_MODE:
    manager.set_debug_mode(True)
    print("Debug mode: ENABLED")

# Load data file
print(f"Loading: {DATA_FILE}")
success = manager.init_from_command_line(["occam", str(DATA_FILE)])

if not success:
    raise Exception(f"Failed to load data file '{DATA_FILE}'")

print("✓ Data loaded successfully")
# Out:
# Loading: /usr/local/lib/python3.12/dist-packages/pyoccam/dementia05.txt
# ✓ Data loaded successfully

# %%
##%%
# Display basic statistics
stats = manager.get_basic_statistics()
print("Data Statistics:")
print(stats)

# Check for test data
has_test = manager.has_test_data()
if has_test:
    print("\n✓ Test data detected - will include test performance metrics")
else:
    print("\nℹ No test data found - using training data only")

# Get variable information
variables = manager.get_variable_list()
print(f"\nVariables ({len(variables)}):")
if len(variables) <= 10:
    for i, var in enumerate(variables):
        print(f"  {i+1:2d}. {var}")
else:
    # Show first and last few
    for i in range(3):
        print(f"  {i+1:2d}. {variables[i]}")
    print("  ...")
    for i in range(len(variables)-2, len(variables)):
        print(f"  {i+1:2d}. {variables[i]}")
# Out:
# Data Statistics:
# Sample size: 424
# Variables: 19
# H(data): 9.72662
# Test data: None
#
#
# ℹ No test data found - using training data only
#
# Variables (19):
#    1. APOE
#    2. Gender
#    3. Education
#   ...
#   18. rs3865444
#   19. CaseControl

# %%
##%%
# Configure OCCAM settings

# Set reference model
manager.set_ref_model("bottom")
print("Reference model: bottom (independence)")

# Set output format
separator = get_separator_constant(OUTPUT_FORMAT)
manager.set_report_separator(separator)
print(f"Output format: {OUTPUT_FORMAT}")

# Configure fit report options
if GENERATE_FIT_REPORT:
    manager.set_fit_classifier_target(FIT_TARGET_STATE)
    manager.set_skip_trained_model_table(SKIP_RESIDUALS)
    manager.set_skip_ivi_tables(SKIP_IVI_TABLES)
    print(f"Fit report target state: {FIT_TARGET_STATE}")

print("\n✓ Configuration complete")
# Out:
# Reference model: bottom (independence)
# Output format: space
# Fit report target state: 0
#
# ✓ Configuration complete

# %%
##%%
# Run search algorithm
print(f"Running {SEARCH_TYPE} search...")
print(f"  Levels: {SEARCH_LEVELS}")
print(f"  Width: {SEARCH_WIDTH}")
print(f"  Test data: {'included' if has_test else 'not available'}")

# Generate search report
search_report = manager.generate_search_report(
    search_type=SEARCH_TYPE,
    levels=SEARCH_LEVELS,
    width=SEARCH_WIDTH,
    include_test_data=has_test
)

print("\n✓ Search complete")
print(f"Models evaluated: {manager.get_search_model_count()}")
# Out:
# Running full-up search...
#   Levels: 7
#   Width: 3
#   Test data: not available
#
# ✓ Search complete
# Models evaluated: 22

# %%
##%%
# Display first part of search report (first 50 lines)
lines = search_report.split('\n')
print(f"Search Report Preview (first 50 lines of {len(lines)} total):")
print("-" * 80)
for line in lines[:50]:
    print(line)
print("-" * 80)
print(f"... ({len(lines)-50} more lines)")
# Out:
# Search Report Preview (first 50 lines of 44 total):
# --------------------------------------------------------------------------------
# Searching levels:
# 1 : 18 new models, 3 kept; 4 total kept
# 2 : 48 new models, 3 kept; 7 total kept
# 3 : 48 new models, 3 kept; 10 total kept
# 4 : 52 new models, 3 kept; 13 total kept
# 5 : 57 new models, 3 kept; 16 total kept
# 6 : 63 new models, 3 kept; 19 total kept
# 7 : 63 new models, 3 kept; 22 total kept
#
#   ID   MODEL                            level              H            ddf            dLR          Alpha        %dH(DV)           daic           dbic      Inc.Alpha       %C(Data)
#   22   IV:ApSxZ:EdZ:AgZ:CZ:KZ               7         9.5505             12       103.4945         0.0000        17.6304        79.4945        30.8977         0.0076        71.6981
#   21   IV:ApSxZ:EdZ:CZ:KZ:LZ                7         9.5515             12       102.9089         0.0000        17.5306        78.9089        30.3121         0.1415        73.3491
#   20   IV:ApSxZ:EdZ:CZ:EZ:KZ                7         9.5517             12       102.8195         0.0000        17.5154        78.8195        30.2227         0.0084        72.6415
#   19*  IV:ApZ:EdZ:AgZ:CZ:KZ                 5         9.5576             10        99.3472         0.0000        16.9239        79.3472        38.8499         0.0056        71.6981
#   18   IV:ApSxZ:EdZ:CZ:KZ                   6         9.5582             10        98.9984         0.0000        16.8644        78.9984        38.5011         0.0035        70.2830
#   17   IV:ApZ:SxZ:EdZ:CZ:KZ                 5         9.5661              9        94.3476         0.0000        16.0722        76.3476        39.9000         0.0026        70.2830
#   16*  IV:ApZ:EdZ:CZ:KZ                     4         9.5665              8        94.1440         0.0000        16.0375        78.1440        45.7461         0.0007        70.0472
#   15   IV:ApSxZ:EdZ:AgZ:CZ                  6         9.5709              9        91.5564         0.0000        15.5967        73.5564        37.1088         0.0450        68.8679
#   14   IV:ApSxZ:EdZ:CZ:EZ                   6         9.5717              9        91.0773         0.0000        15.5151        73.0773        36.6297         0.0572        70.0472
#   13*  IV:ApZ:EdZ:AgZ:CZ                    4         9.5791              7        86.7343         0.0000        14.7752        72.7343        44.3862         0.0318        70.2830
#   12   IV:ApSxZ:EdZ:CZ                      5         9.5814              7        85.3534         0.0000        14.5400        71.3534        43.0053         0.0218        70.0472
#   11*  IV:ApZ:EdZ:KZ                        3         9.5870              6        82.0689         0.0000        13.9805        70.0689        45.7705         0.0003        69.8113
#   10   IV:ApZ:SxZ:EdZ:CZ                    4         9.5903              6        80.1082         0.0000        13.6465        68.1082        43.8098         0.6024        69.5755
#    9*  IV:ApZ:EdZ:CZ                        3         9.5908              5        79.8373         0.0000        13.6003        69.8373        49.5886         0.0010        69.5755
#    8*  IV:ApZ:CZ:KZ                         3         9.5910              6        79.7227         0.0000        13.5808        67.7227        43.4243         0.0009        68.6321
#    7*  IV:ApZ:EdZ                           2         9.6133              3        66.5901         0.0000        11.3437        60.5901        48.4409         0.0000        69.5755
#    6*  IV:ApZ:CZ                            2         9.6144              3        65.9506         0.0000        11.2347        59.9506        47.8014         0.0000        67.9245
#    5*  IV:ApZ:KZ                            2         9.6150              4        65.6244         0.0000        11.1792        57.6244        41.4255         0.0024        66.9811
#    4*  IV:ApZ                               1         9.6396              1        51.1652         0.0000         8.7160        49.1652        45.1155         0.0000        66.9811
#    3*  IV:CZ                                1         9.6998              2        15.7735         0.0004         2.6870        11.7735         3.6740         0.0004        58.0189
#    2*  IV:EdZ                               1         9.7009              2        15.1356         0.0005         2.5784        11.1356         3.0361         0.0005        56.3679
#    1*  IV:Z                                 0         9.7266              0         0.0000         1.0000         0.0000         0.0000         0.0000         0.0000        52.1226
#   ID   MODEL                            level              H            ddf            dLR          Alpha        %dH(DV)           daic           dbic      Inc.Alpha       %C(Data)
#
#
# Best Model(s) by dBIC:
#    9*  IV:ApZ:EdZ:CZ                        3         9.5908              5        79.8373         0.0000        13.6003        69.8373        49.5886         0.0010        69.5755
# Best Model(s) by dAIC:
#   22   IV:ApSxZ:EdZ:AgZ:CZ:KZ               7         9.5505             12       103.4945         0.0000        17.6304        79.4945        30.8977         0.0076        71.6981
# Best Model(s) by Information, with all Inc. Alpha < 0.05:
#   19*  IV:ApZ:EdZ:AgZ:CZ:KZ                 5         9.5576             10        99.3472         0.0000        16.9239        79.3472        38.8499         0.0056        71.6981
#
#
#
# --------------------------------------------------------------------------------
# ... (-6 more lines)

# %%
##%%
# Get best models by different criteria
best_models = {
    "bic": manager.get_best_model_by_bic(),
    "aic": manager.get_best_model_by_aic(),
    "information": manager.get_best_model_by_information(),
    "info_alpha": manager.get_best_model_by_info_alpha()
}

print("Best models found:")
for criterion, model_name in best_models.items():
    if model_name:
        print(f"  {criterion.upper():12s}: {model_name}")
    else:
        print(f"  {criterion.upper():12s}: (none found)")
# Out:
# Best models found:
#   BIC         : IV:ApZ:EdZ:CZ
#   AIC         : IV:ApSxZ:EdZ:AgZ:CZ:KZ
#   INFORMATION : IV:ApSxZ:EdZ:AgZ:CZ:KZ
#   INFO_ALPHA  : IV:ApZ:EdZ:AgZ:CZ:KZ

# %%
##%%
# Select model based on configured criterion
selected_model = best_models.get(BEST_MODEL_CRITERION)

if not selected_model:
    print(f"WARNING: No model found using criterion '{BEST_MODEL_CRITERION}'")
    selected_model = best_models.get("information")
    if selected_model:
        print(f"Falling back to best by information: {selected_model}")

if not selected_model:
    raise Exception("No models found in search results")

print(f"\n✓ Selected model (by {BEST_MODEL_CRITERION}): {selected_model}")
# Out:
# ✓ Selected model (by bic): IV:ApZ:EdZ:CZ

# %%
##%%
# Select model based on configured criterion
selected_model = best_models.get(BEST_MODEL_CRITERION)

if not selected_model:
    print(f"WARNING: No model found using criterion '{BEST_MODEL_CRITERION}'")
    selected_model = best_models.get("information")
    if selected_model:
        print(f"Falling back to best by information: {selected_model}")

if not selected_model:
    raise Exception("No models found in search results")

print(f"\n✓ Selected model (by {BEST_MODEL_CRITERION}): {selected_model}")
# Out:
# ✓ Selected model (by bic): IV:ApZ:EdZ:CZ

# %%
##%%
# Get detailed statistics for selected model
model_stats = manager.get_model_statistics(selected_model)

print(f"Selected model statistics for: {selected_model}")
print("-" * 50)
print(f"  Entropy (H):        {model_stats.h:.4f}")
print(f"  Information:        {model_stats.information:.4f} ({model_stats.information*100:.2f}%)")
print(f"  Degrees of freedom: {model_stats.df:.0f}")
print(f"  Likelihood ratio:   {model_stats.lr:.4f}")
print(f"  Alpha (p-value):    {model_stats.alpha:.6f}")
print(f"  AIC:                {model_stats.aic:.4f}")
print(f"  BIC:                {model_stats.bic:.4f}")
print(f"  Delta AIC:          {model_stats.daic:.4f}")
print(f"  Delta BIC:          {model_stats.dbic:.4f}")

if has_test:
    print(f"\nTest Data Performance:")
    print(f"  % Correct (train):  {model_stats.pct_correct_data:.2f}%")
    print(f"  % Correct (test):   {model_stats.pct_correct_test:.2f}%")
    print(f"  % Coverage:         {model_stats.pct_coverage:.2f}%")
    print(f"  % Missed (test):    {model_stats.pct_missed_test:.2f}%")
else:
    print(f"  % Correct (data):   {model_stats.pct_correct_data:.2f}%")
# Out:
# Selected model statistics for: IV:ApZ:EdZ:CZ
# --------------------------------------------------
#   Entropy (H):        9.5908
#   Information:        0.1360 (13.60%)
#   Degrees of freedom: 5
#   Likelihood ratio:   79.8373
#   Alpha (p-value):    0.000000
#   AIC:                69.8373
#   BIC:                49.5886
#   Delta AIC:          69.8373
#   Delta BIC:          49.5886
#   % Correct (data):   69.58%

# %%
##%%
if GENERATE_FIT_REPORT:
    print(f"Generating fit report for: {selected_model}")
    print(f"Target state: {FIT_TARGET_STATE}")

    # Generate fit report
    fit_report = manager.generate_fit_report(
        model_name=selected_model,
        target_state=FIT_TARGET_STATE
    )

    # Save fit report
    fit_filename = f"fit_{selected_model.replace(':', '_')}.txt"
    fit_path = save_output(fit_report, fit_filename)

    print("\n✓ Fit report generated")
    print("Includes:")
    print("  • Model statistics")
    print("  • Contingency table")
    if not SKIP_RESIDUALS:
        print("  • Residual analysis")
    if not SKIP_IVI_TABLES:
        print("  • IVI tables")
    print("  • Confusion matrix")
    if has_test:
        print("  • Test data performance")
else:
    print("Fit report generation skipped (GENERATE_FIT_REPORT = False)")
# Out:
# Generating fit report for: IV:ApZ:EdZ:CZ
# Target state: 0
# Saved to: notebook_output/fit_IV_ApZ_EdZ_CZ.txt
#
# ✓ Fit report generated
# Includes:
#   • Model statistics
#   • Contingency table
#   • Residual analysis
#   • IVI tables
#   • Confusion matrix

# %%
import pyoccam

print("=== PYOCCAM DIAGNOSTIC TEST ===\n")

print("Step 1: Initialize manager...")
manager = pyoccam.VBMManager()
print("✓ Manager created\n")

print("Step 2: Load data...")
success = manager.init_from_command_line(["occam", "dementia05.txt"])
print(f"✓ Data loaded: {success}\n")

print("Step 3: Test make_model with False parameter...")
try:
    model = manager.make_model("IV:ApZ", False)
    print(f"✓ Model created with False: {model.name}")
except Exception as e:
    print(f"✗ Error with False: {e}")

print("\nStep 4: Test make_model with True parameter...")
print("(This might hang - if it does, we know the issue)")
try:
    model2 = manager.make_model("IV:ApZ", True)
    print(f"✓ Model created with True: {model2.name}")
except Exception as e:
    print(f"✗ Error with True: {e}")

print("\nStep 5: If we get here, try generate_fit_report...")
try:
    report = manager.generate_fit_report("IV:ApZ", "0")
    print(f"✓ Report generated: {len(report)} chars")
except Exception as e:
    print(f"✗ Error: {e}")

print("\n=== END DIAGNOSTIC ===")
