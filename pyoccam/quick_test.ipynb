# %%
# For Jupyter Notebook - Current working version:

import pyoccam

# Setup
manager = pyoccam.VBMManager()
manager.set_debug_mode(True)
manager.init_from_command_line(["occam", "dementia05.txt"])

# 🔧 Search with current implementation (parameter config in progress)
result = manager.generate_search_report("full-up", levels=7, width=3)
print(result)

# Status: Search works, parameter configuration being developed
# Out:
# OCCAM Search Report - FIXED PARAMETERS
# Search: full-up, Levels: 7, Width: 3
# Data: dementia05.txt
# Generated: Tue Jul 29 00:53:11 2025
#
# ID	MODEL	Level	H	dDF	dLR	Alpha	Inf	%dH(DV)	dAIC	dBIC	Inc.Alpha	%C(Data)	%cover
# 1	IV:ApZ	1	9.6396	1	51.1652	0.0000	0.0872	0.90	49.1652	45.1155	-1.0000	66.98	-1.00
# 2	IV:SxZ	1	9.7236	1	1.7501	0.1861	0.0030	0.03	-0.2499	-4.2996	-1.0000	53.54	-1.00
# 3	IV:EdZ	1	9.7009	2	15.1356	0.0005	0.0258	0.27	11.1356	3.0361	-1.0000	56.37	-1.00
# 4	IV:AgZ	1	9.7144	2	7.2089	0.0272	0.0123	0.13	3.2089	-4.8906	-1.0000	55.90	-1.00
# 5	IV:AZ	1	9.7197	2	4.0717	0.1306	0.0069	0.07	0.0717	-8.0278	-1.0000	55.19	-1.00
# 6	IV:BZ	1	9.7169	3	5.7348	0.1235	0.0098	0.10	-0.2652	-12.4144	-1.0000	52.12	-1.00
# 7	IV:CZ	1	9.6998	2	15.7735	0.0004	0.0269	0.28	11.7735	3.6740	-1.0000	58.02	-1.00
# 8	IV:DZ	1	9.7188	2	4.6115	0.0997	0.0079	0.08	0.6115	-7.4880	-1.0000	54.95	-1.00
# 9	IV:EZ	1	9.7184	2	4.8474	0.0886	0.0083	0.08	0.8474	-7.2521	-1.0000	55.42	-1.00
# ...
